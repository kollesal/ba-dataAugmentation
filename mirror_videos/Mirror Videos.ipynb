# %%
# !pip install moviepy

# %%
from moviepy.editor import VideoFileClip, vfx
for i in range(1, 77):
    clip = VideoFileClip('vids/'+str(i)+'_trinken_normal_raw1.mp4')
    reversed_clip = clip.fx(vfx.mirror_x)
    reversed_clip.write_videofile('mirror/'+str(i)+'_trinken_normal_raw1.mp4')
# Out:
# ...
# chunk:  35%|█████████████████████▊                                         | 78/225 [00:00<00:00, 774.13it/s, now=None]
# Moviepy - Building video mirror/3_trinken_normal_raw1.mp4.
# MoviePy - Writing audio in 3_trinken_normal_raw1TEMP_MPY_wvf_snd.mp3
# ...
# t:   1%|▉                                                                    | 4/306 [00:00<00:08, 33.70it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video mirror/3_trinken_normal_raw1.mp4
# ...
# t:   1%|▍                                                                | 2/306 [30:52<78:12:23, 926.13s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready mirror/3_trinken_normal_raw1.mp4
# ...
# chunk:  35%|██████████████████████                                         | 79/225 [00:00<00:00, 788.11it/s, now=None]
# Moviepy - Building video mirror/4_trinken_normal_raw1.mp4.
# MoviePy - Writing audio in 4_trinken_normal_raw1TEMP_MPY_wvf_snd.mp3
# ...
